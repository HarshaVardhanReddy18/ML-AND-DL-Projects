# %%
import tkinter as tk

from tkinter import font

from selenium import webdriver

import pyautogui as py

from time import sleep

height = 800
width = 1500

root = tk.Tk()

root.title("CHROME DRIVER")


app = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/app.png")
googlepic = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/google.png")
youtubepic = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/youtube.png")
saavnpic = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/saavn.png")
gmailpic = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/gmail.png")
netflixpic = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/netflix.png")
primepic = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/prime.png")
fbpic = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/fbpic.png")
apic = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/ama.png")
inpic = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/instaa.png")
gcon = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/gcon.png")
ycon = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/ycon.png")
gmcon = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/gmcon.png")
ncon = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/ncon.png")
pcon = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/pcon.png")
scon = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/scon.png")
fcon = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/fb.png")
acon = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/acon.png")
icon = tk.PhotoImage(file = "C:/Users/H/Pictures/Saved Pictures/insta.png")

class google:
    def __init__(self):
        self.driver = webdriver.Chrome("C:/Users/H/Documents/chrome/chromedriver.exe")
        self.driver.get("https:www.google.com/search?q=" + str(searchbox.get()))
        
class youtube:
    def __init__(self,songname):
        self.driver = webdriver.Chrome("C:/Users/H/Documents/chrome/chromedriver.exe")
        self.driver.get("https://www.youtube.com/results?search_query="+str(songname))
        
        
class saavn:
    def __init__(self,songname):
        self.driver = webdriver.Chrome("C:/Users/H/Documents/chrome/chromedriver.exe")
        self.driver.get("https://www.saavn.com/search/"+str(songname))
    
class gmaillogin:
    def __init__(self,username,pw):
        self.browser = webdriver.Chrome("C:/Users/H/Documents/chrome/chromedriver.exe")
        self.browser.get("https://www.gmail.com/")
        sleep(2)
        self.browser.find_element_by_xpath("/html/body/div[1]/div[1]/div[2]/div/div[2]/div/div/div[2]/div/div[1]/div/form/span/section/div/div/div[1]/div/div[1]/div/div[1]/input").send_keys(username)
        self.browser.find_element_by_xpath("/html/body/div[1]/div[1]/div[2]/div/div[2]/div/div/div[2]/div/div[2]/div/div[1]/div").click()
        sleep(3)
        self.browser.find_element_by_xpath("/html/body/div[1]/div[1]/div[2]/div/div[2]/div/div/div[2]/div/div[1]/div/form/span/section/div/div/div[1]/div[1]/div/div/div/div/div[1]/div/div[1]/input").send_keys(pw)
        self.browser.find_element_by_xpath("/html/body/div[1]/div[1]/div[2]/div/div[2]/div/div/div[2]/div/div[2]/div/div[1]/div").click()
        sleep(10)
        self.browser.find_element_by_xpath("/html/body/div[7]/div[3]/div/div[2]/div[1]/div[1]/div[1]/div/div/div/div[1]/div/div").click()
        sleep(15)

class netflix:
    def __init__(self,username,pw):
        self.driver = webdriver.Chrome("C:/Users/H/Documents/chrome/chromedriver.exe")
        self.driver.get("https:/www.netflix.com/in/login")
        self.driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div/div/div[1]/form/div[1]/div[1]/div/label/input").send_keys(username)
        sleep(2)
        self.driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div/div/div[1]/form/div[2]/div[1]/div/label/input").send_keys(pw)
        sleep(1)
        self.driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div/div/div[1]/form/button").click()        

        
class prime:
    def __init__(self,username,pw):
        self.browser = webdriver.Chrome("C:/Users/H/Documents/chrome/chromedriver.exe")
        self.browser.get("https:www.primevideo.com")
        self.browser.find_element_by_xpath("/html/body/div[2]/header/div/div/span/span/span/a").click()
        sleep(1)
        self.browser.find_element_by_xpath("/html/body/div[1]/div[1]/div[2]/div/div[2]/div/div/form/div/div/div/div[1]/input").send_keys(username)
        sleep(1)
        self.browser.find_element_by_xpath("/html/body/div[1]/div[1]/div[2]/div/div[2]/div/div/form/div/div/div/div[2]/input").send_keys(pw)
        sleep(1)
        self.browser.find_element_by_xpath("/html/body/div[1]/div[1]/div[2]/div/div[2]/div/div/form/div/div/div/div[3]/span/span/input").click()

        
class fb:
    def __init__(self,username,pw):
        self.driver = webdriver.Chrome("C:/Users/H/Documents/chrome/chromedriver.exe")
        self.driver.get("https://www.facebook.com")
        self.driver.find_element_by_xpath("/html/body/div[1]/div[2]/div/div/div/div/div[2]/form/table/tbody/tr[2]/td[1]/input").send_keys(username)
        sleep(1)
        self.driver.find_element_by_xpath("/html/body/div[1]/div[2]/div/div/div/div/div[2]/form/table/tbody/tr[2]/td[2]/input").send_keys(pw)
        sleep(1)
        self.driver.find_element_by_xpath("/html/body/div[1]/div[2]/div/div/div/div/div[2]/form/table/tbody/tr[2]/td[3]/label/input").click()
        
class amazon:
    def __init__(self,search):
        self.browser = webdriver.Chrome("C:/Users/H/Documents/chrome/chromedriver.exe")
        self.browser.get("https://www.amazon.in")
        sleep(1)
        self.browser.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[3]/div/form/div[3]/div[1]/input").send_keys(search)
        sleep(1)
        self.browser.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[3]/div/form/div[2]/div/input").click()
        sleep(1)

        
class insta:
    def __init__(self,username,pw):
        self.browser = webdriver.Chrome("C:/Users/H/Documents/chrome/chromedriver.exe")
        self.browser.get("https://www.instagram.com")
        sleep(2)
        self.browser.find_element_by_xpath("/html/body/div[1]/section/main/article/div[2]/div[1]/div/form/div[2]/div/label/input").send_keys(username)
        self.browser.find_element_by_xpath("/html/body/div[1]/section/main/article/div[2]/div[1]/div/form/div[3]/div/label/input").send_keys(pw)
        sleep(1)
        self.browser.find_element_by_xpath("/html/body/div[1]/section/main/article/div[2]/div[1]/div/form/div[4]/button/div").click()

        
        
def rise(frame):
    frame.tkraise()



canvas = tk.Canvas(root,height = height,width = width)
canvas.pack()

mmainframe = tk.Frame(canvas,bg = 'white')
mmainframe.place(relheight = 1,relwidth = 1)

mmainlabel = tk.Label(mmainframe,bg = 'white')
mmainlabel.place(relheight = 1,relwidth = 1)

mmainbutton = tk.Button(mmainlabel,image = app,bg = 'white',command = lambda : rise(mainframe))
mmainbutton.place(relx = .4,rely = .37,relheight = .25,relwidth = .175)

clicklabel = tk.Label(mmainlabel,text = '(:HELLO WORLD:)',bg = 'white',fg = 'black',font = ('Gabriola',25))
clicklabel.place(relx = .4,rely = .63,relheight = .05,relwidth = .175)

mainframe = tk.Frame(canvas)
mainframe.place(relheight = 1,relwidth = 1)

mainlabel = tk.Label(mainframe,bg = 'black')
mainlabel.place(relheight = 1,relwidth = 1)

mback = tk.Button(mainlabel,bg = 'black',text = 'Back',fg = 'white',font = ('Arial',25),command = lambda: rise(mmainframe))
mback.place(relx = .85,rely = .03,relheight = .05,relwidth = .1)

googlebutton = tk.Button(mainlabel,text = 'GOOGLE',bg = 'black',fg = 'black',command = lambda : rise(googleframe),image = gcon)
googlebutton.place(relx = .1,rely = .1,relheight = .2,relwidth = .15)
    
    
youtubebutton = tk.Button(mainlabel,text = 'YOUTUBE',bg = 'black',fg = 'black',command = lambda : rise(youtubeframe),image = ycon)
youtubebutton.place(relx = .1,rely = .4,relheight = .2,relwidth = .15)
    
saavnbutton = tk.Button(mainlabel,text = 'SAAVN',bg = 'black',fg = 'black',command = lambda : rise(saavnframe),image = scon)
saavnbutton.place(relx = .8,rely = .4,relheight = .2,relwidth = .15)

gmailbutton = tk.Button(mainlabel,text = 'GMAIL',bg = 'black',fg = 'black',command = lambda : rise(gmailframe),image = gmcon)
gmailbutton.place(relx = .1,rely = .7,relheight = .2,relwidth = .15)

netflixbutton = tk.Button(mainlabel,text = 'NETFLIX',bg = 'black',fg = 'black',command = lambda : rise(netflixframe),image = ncon)
netflixbutton.place(relx = .45,rely = .1,relheight = .2,relwidth = .15)
    
primebutton = tk.Button(mainlabel,text = 'PRIME VIDEO',bg = 'black',fg = 'black',command = lambda : rise(primeframe),image = pcon)
primebutton.place(relx = .8,rely = .1,relheight = .2,relwidth = .15)

fbutton = tk.Button(mainlabel,image = fcon,bg = 'black',command = lambda : rise(fbframe))
fbutton.place(relx = .45,rely = .4,relheight = .2,relwidth = .15)

abutton = tk.Button(mainlabel,image = acon,bg = 'black',command = lambda : rise(aframe))
abutton.place(relx = .45,rely = .7,relheight = .2,relwidth = .15)

inbutton = tk.Button(mainlabel,image = icon,bg = 'black',command = lambda : rise(inframe))
inbutton.place(relx = .8,rely = .7,relheight = .2,relwidth = .15)


googleframe = tk.Frame(canvas)
googleframe.place(relheight = 1,relwidth = 1)

googlelabel = tk.Label(googleframe,image = googlepic)
googlelabel.place(relheight = 1,relwidth = 1)

searchbox = tk.Entry(googleframe,font = ('Gabriola',20))
searchbox.place(relx = .22,rely = .575,relwidth = .5,relheight = .05)

searchbutton = tk.Button(googleframe,text = 'Search',bg = 'white',fg = '#4d4d4d',command = lambda : google(),font = ('Arial',20))
searchbutton.place(relx = .77,rely = .575,relwidth = .15,relheight = .05)

backbutton = tk.Button(googleframe,text = 'Back',bg = 'white',fg = '#4d4d4d',command = lambda : rise(mainframe),font = ('Arial',20))
backbutton.place(relx = .77,rely = .1,relwidth = .15,relheight = .05)


youtubeframe = tk.Frame(canvas)
youtubeframe.place(relheight = 1,relwidth = 1)

youtubelabel = tk.Label(youtubeframe,image = youtubepic)
youtubelabel.place(relheight = 1,relwidth = 1)

ysearchbox = tk.Entry(youtubeframe,font = ('Gabriola',20))
ysearchbox.place(relx = .22,rely = .62,relwidth = .5,relheight = .05)

ysearchbutton = tk.Button(youtubeframe,text = 'Search',bg = 'white',fg = '#fb000f',font = ('Arial',20),command = lambda : youtube(ysearchbox.get()))
ysearchbutton.place(relx = .77,rely = .62,relwidth = .15,relheight = .05)


ybackbutton = tk.Button(youtubeframe,text = 'Back',bg = 'white',fg = '#fb000f',command = lambda : rise(mainframe),font = ('Arial',20))
ybackbutton.place(relx = .77,rely = .1,relwidth = .15,relheight = .05)


saavnframe = tk.Frame(canvas)
saavnframe.place(relheight = 1, relwidth = 1)

saavnlabel = tk.Label(saavnframe,image = saavnpic)
saavnlabel.place(relheight = 1,relwidth = 1)

ssearchbox = tk.Entry(saavnframe,font = ('Gabriola',20))
ssearchbox.place(relx = .22,rely = .8,relwidth = .5,relheight = .05)

ssearchbutton = tk.Button(saavnframe,text = 'Search',bg = 'white',fg = '#30b55a',font = ('Arial',20),command = lambda : saavn(ssearchbox.get()))
ssearchbutton.place(relx = .77,rely = .8,relwidth = .15,relheight = .05)

sbackbutton = tk.Button(saavnframe,text = 'Back',bg = 'white',fg = '#30b55a',command = lambda : rise(mainframe),font = ('Arial',20))
sbackbutton.place(relx = .77,rely = .1,relwidth = .15,relheight = .05)

gmailframe = tk.Frame(canvas)
gmailframe.place(relheight = 1, relwidth = 1)

gmaillabel = tk.Label(gmailframe,image = gmailpic)
gmaillabel.place(relheight = 1,relwidth = 1)

userbox = tk.Entry(gmailframe,font = ('Arial',20))
userbox.place(relx = .4,rely = .7,relheight = .05,relwidth = .35)

pwbox = tk.Entry(gmailframe,font = ('Arial',20),show=  '*')
pwbox.place(relx = .4,rely = .8,relheight = .05,relwidth = .35)

userlabel = tk.Label(gmailframe,text = 'Username',bg = '#266392',fg= 'white',font = ('Arial',20))
userlabel.place(relx = .22,rely = .7,relheight = .05,relwidth = .12)

pwlabel = tk.Label(gmailframe,text = 'Password',bg = '#266392',fg= 'white',font = ('Arial',20))
pwlabel.place(relx = .22,rely = .8,relheight = .05,relwidth = .12)

signinbutton = tk.Button(gmailframe,text = 'Sign In',bg = '#276493',fg = 'white',font = ('Arial',20),command = lambda: gmaillogin(userbox.get(),pwbox.get()))
signinbutton.place(relx = .77,rely = .9,relheight = .05,relwidth = .1)

gbackbutton = tk.Button(gmailframe,text = 'Back',bg = '#276493',fg = 'white',font = ('Arial',20),command = lambda: rise(mainframe))
gbackbutton.place(relx = .77,rely = .1,relwidth = .15,relheight = .05)

netflixframe = tk.Frame(canvas)
netflixframe.place(relheight = 1, relwidth = 1)

netflixlabel = tk.Label(netflixframe,image = netflixpic)
netflixlabel.place(relheight = 1,relwidth = 1)

nuserbox = tk.Entry(netflixframe,font = ('Arial',20))
nuserbox.place(relx = .2,rely = .25,relheight = .05,relwidth = .35)

npwbox = tk.Entry(netflixframe,font = ('Arial',20),show=  '*')
npwbox.place(relx = .2,rely = .35,relheight = .05,relwidth = .35)

nuserlabel = tk.Label(netflixframe,text = 'E-mail/Phone',bg = '#932321',fg= 'white',font = ('Arial',20))
nuserlabel.place(relx = .02,rely = .25,relheight = .05,relwidth = .15)

npwlabel = tk.Label(netflixframe,text = 'Password',bg = '#932321',fg= 'white',font = ('Arial',20))
npwlabel.place(relx = .05,rely = .35,relheight = .05,relwidth = .12)

nsigninbutton = tk.Button(netflixframe,text = 'Sign In',bg = '#ac2627',fg = 'white',font = ('Arial',20),command = lambda: netflix(nuserbox.get(),npwbox.get()))
nsigninbutton.place(relx = .45,rely = .5,relheight = .05,relwidth = .1)

nbackbutton = tk.Button(netflixframe,text = 'Back',bg = '#8b181b',fg = 'white',font = ('Arial',20),command = lambda: rise(mainframe))
nbackbutton.place(relx = .6,rely = .10,relwidth = .15,relheight = .05)

primeframe = tk.Frame(canvas)
primeframe.place(relheight = 1, relwidth = 1)

primelabel = tk.Label(primeframe,image = primepic)
primelabel.place(relheight = 1,relwidth = 1)

puserbox = tk.Entry(primeframe,font = ('Arial',20))
puserbox.place(relx = .4,rely = .5,relheight = .05,relwidth = .35)

ppwbox = tk.Entry(primeframe,font = ('Arial',20),show=  '*')
ppwbox.place(relx = .4,rely = .6,relheight = .05,relwidth = .35)

puserlabel = tk.Label(primeframe,text = 'E-mail/Phone',bg = '#212121',fg= 'white',font = ('Arial',20))
puserlabel.place(relx = .20,rely = .5,relheight = .05,relwidth = .2)

ppwlabel = tk.Label(primeframe,text = 'Password',bg = '#212121',fg= 'white',font = ('Arial',20))
ppwlabel.place(relx = .25,rely = .6,relheight = .05,relwidth = .12)

psigninbutton = tk.Button(primeframe,text = 'Sign In',bg = '#83aa3f',fg = 'white',font = ('Arial',20),command = lambda: prime(puserbox.get(),ppwbox.get()))
psigninbutton.place(relx = .7,rely = .75,relheight = .05,relwidth = .1)

pbackbutton = tk.Button(primeframe,text = 'Back',bg = '#212121',fg = 'white',font = ('Arial',20),command = lambda: rise(mainframe))
pbackbutton.place(relx = .75,rely = .10,relwidth = .15,relheight = .05)

fbframe = tk.Frame(canvas)
fbframe.place(relheight = 1, relwidth = 1)

fblabel = tk.Label(fbframe,image = fbpic)
fblabel.place(relheight = 1,relwidth = 1)

fuserbox = tk.Entry(fbframe,font = ('Arial',20))
fuserbox.place(relx = .55,rely = .25,relheight = .05,relwidth = .35)

fpwbox = tk.Entry(fbframe,font = ('Arial',20),show=  '*')
fpwbox.place(relx = .55,rely = .35,relheight = .05,relwidth = .35)

fuserlabel = tk.Label(fbframe,text = 'E-mail/Phone',bg = '#3b5999',fg= 'white',font = ('Arial',20))
fuserlabel.place(relx = .3,rely = .25,relheight = .05,relwidth = .2)

fpwlabel = tk.Label(fbframe,text = 'Password',bg = '#3b5999',fg= 'white',font = ('Arial',20))
fpwlabel.place(relx = .325,rely = .35,relheight = .05,relwidth = .12)

fsigninbutton = tk.Button(fbframe,text = 'Sign In',bg = '#3b5999',fg = 'white',font = ('Arial',20),command = lambda: fb(fuserbox.get(),fpwbox.get()))
fsigninbutton.place(relx = .8,rely = .475,relheight = .05,relwidth = .1)

fbackbutton = tk.Button(fbframe,text = 'Back',bg = '#3b5999',fg = 'white',font = ('Arial',20),command = lambda: rise(mainframe))
fbackbutton.place(relx = .8,rely = .07,relwidth = .15,relheight = .05)

aframe = tk.Frame(canvas)
aframe.place(relheight = 1, relwidth = 1)

alabel = tk.Label(aframe,image = apic)
alabel.place(relheight = 1,relwidth = 1)

abackbutton = tk.Button(aframe,text = 'Back',bg = 'black',fg = '#ed9402',font = ('Arial',20),command = lambda: rise(mainframe))
abackbutton.place(relx = .8,rely = .07,relwidth = .15,relheight = .05)

asearchbox = tk.Entry(aframe,font = ('Gabriola',20))
asearchbox.place(relx = .22,rely = .75,relwidth = .5,relheight = .05)

asearchbutton = tk.Button(aframe,text = 'Search for product',bg = 'black',fg = '#ed9402',font = ('Arial',20),command = lambda : amazon(asearchbox.get()))
asearchbutton.place(relx = .77,rely = .75,relwidth = .2,relheight = .05)

inframe = tk.Frame(canvas)
inframe.place(relheight = 1, relwidth = 1)

inlabel = tk.Label(inframe,image = inpic)
inlabel.place(relheight = 1,relwidth = 1)

inbox = tk.Entry(inframe,font = ('Arial',20))
inbox.place(relx = .55,rely = .25,relheight = .05,relwidth = .35)

ipwbox = tk.Entry(inframe,font = ('Arial',20),show=  '*')
ipwbox.place(relx = .55,rely = .35,relheight = .05,relwidth = .35)

inlabel = tk.Label(inframe,text = 'Email/Phone',bg = '#b82c9c',fg= 'white',font = ('Arial',20))
inlabel.place(relx = .38,rely = .25,relheight = .05,relwidth = .15)

ipwlabel = tk.Label(inframe,text = 'Password',bg = '#cd288e',fg= 'white',font = ('Arial',20))
ipwlabel.place(relx = .38,rely = .35,relheight = .05,relwidth = .15)

isigninbutton = tk.Button(inframe,text = 'Sign In',bg = '#be2a98',fg = 'white',font = ('Arial',20),command = lambda: insta(inbox.get(),ipwbox.get()))
isigninbutton.place(relx = .79,rely = .48,relheight = .05,relwidth = .1)

ibackbutton = tk.Button(inframe,text = 'Back',bg = '#4e5fd3',fg = 'white',font = ('Arial',20),command = lambda: rise(mainframe))
ibackbutton.place(relx = .8,rely = .1,relwidth = .15,relheight = .05)


mmainframe.tkraise()

menubar = tk.Menu(root)
filemenu = tk.Menu(menubar, tearoff=0)
filemenu.add_command(label = 'GOOGLE',command = lambda : rise(googleframe))
filemenu.add_command(label = 'YOUTUBE',command = lambda: rise(youtubeframe))
filemenu.add_command(label = 'NETFLIX',command = lambda: rise(netflixframe))
filemenu.add_command(label = 'INSTAGRAM',command = lambda: rise(inframe))
filemenu.add_command(label = 'PRIME',command = lambda: rise(primeframe))
filemenu.add_command(label = 'SAAVN',command = lambda: rise(saavnframe))
filemenu.add_command(label = 'AMAZON',command = lambda: rise(aframe))
filemenu.add_command(label = 'FACEBOOK',command = lambda: rise(fbframe))
filemenu.add_command(label = 'GMAIL',command = lambda: rise(gmailframe))


filemenu.add_separator()

filemenu.add_command(label = 'Exit',command = root.quit)

menubar.add_cascade(label = 'APPS',menu = filemenu)

root.config(menu = menubar)

root.mainloop()
